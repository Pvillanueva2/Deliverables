# %% [markdown]
# First Deliverables
#
# New Global HIV Cases

# %%
import pandas as pd

file2021="2021.xlsx"
file2020="2020.xlsx"

#reading the files

fragil2021=pd.read_excel(file2021)
fragil2020=pd.read_excel(file2020)

# %%
set(fragil2021) & set(fragil2020)
#looking at the columns
# Out:
# {'Cases', 'Country Code', 'Country Name', 'Series Code', 'Series Name', 'Year'}

# %%
common=set(fragil2021.columns)&set(fragil2020)

fragil2021ap=fragil2021.loc[:,common]
fragil2020ap=fragil2020.loc[:,common]

#looking at the common columns
# Out:
# /var/folders/sv/1bpgx38n2yn14wm9qk7cqmrc0000gn/T/ipykernel_33421/2930108011.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   fragil2021ap=fragil2021.loc[:,common]
# /var/folders/sv/1bpgx38n2yn14wm9qk7cqmrc0000gn/T/ipykernel_33421/2930108011.py:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   fragil2020ap=fragil2020.loc[:,common]

# %%
theZips = zip (fragil2021ap.dtypes,
              fragil2020ap.dtypes)

list(theZips)
#looking at data type
# Out:
# [(dtype('float64'), dtype('float64')),
#  (dtype('O'), dtype('O')),
#  (dtype('O'), dtype('O')),
#  (dtype('O'), dtype('O')),
#  (dtype('O'), dtype('O')),
#  (dtype('O'), dtype('O'))]

# %%
theZips = zip(fragil2021ap.dtypes,
             fragil2021ap.dtypes)
[x for x in theZips if len(set(x))>1]

#looking if there's any
# Out:
# []

# %%
fragil2020ap.dropna(inplace=True)

# %%
fragil2020ap.Year=[int(x) for x in fragil2020ap.Year]

# %%
fragil2020ap
# Out:
#      Year    Cases                                        Series Name  \
# 0    2020     1300  Adults (ages 15+) and children (ages 0-14) new...
# 1    2020       ..  Adults (ages 15+) and children (ages 0-14) new...
# 2    2020       ..  Adults (ages 15+) and children (ages 0-14) new...
# 3    2020      100  Adults (ages 15+) and children (ages 0-14) new...
# 4    2020     1900  Adults (ages 15+) and children (ages 0-14) new...
# ..    ...      ...                                                ...
# 261  2020       ..  Adults (ages 15+) and children (ages 0-14) new...
# 262  2020  1500000  Adults (ages 15+) and children (ages 0-14) new...
# 263  2020     1100  Adults (ages 15+) and children (ages 0-14) new...
# 264  2020    42000  Adults (ages 15+) and children (ages 0-14) new...
# 265  2020    25000  Adults (ages 15+) and children (ages 0-14) new...
#
#         Series Code Country Code                 Country Name
# 0    SH.HIV.INCD.TL          AFG                  Afghanistan
# ...

# %%
fragil2021ap.dropna(inplace=True)

# %%
fragil2021ap.Year=[int(x) for x in fragil2021ap.Year]

# %%
fragil2021ap.Year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 261    2020
# 262    2020
# 263    2020
# 264    2020
# 265    2020
# Name: Year, Length: 266, dtype: int64

# %%
fragil2021ap
# Out:
#      Year    Cases                                        Series Name  \
# 0    2020     1500  Adults (ages 15+) and children (ages 0-14) new...
# 1    2020       ..  Adults (ages 15+) and children (ages 0-14) new...
# 2    2020       ..  Adults (ages 15+) and children (ages 0-14) new...
# 3    2020      100  Adults (ages 15+) and children (ages 0-14) new...
# 4    2020     2000  Adults (ages 15+) and children (ages 0-14) new...
# ..    ...      ...                                                ...
# 261  2020       ..  Adults (ages 15+) and children (ages 0-14) new...
# 262  2020  1500000  Adults (ages 15+) and children (ages 0-14) new...
# 263  2020     1100  Adults (ages 15+) and children (ages 0-14) new...
# 264  2020    38000  Adults (ages 15+) and children (ages 0-14) new...
# 265  2020    23000  Adults (ages 15+) and children (ages 0-14) new...
#
#         Series Code Country Code                 Country Name
# 0    SH.HIV.INCD.TL          AFG                  Afghanistan
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 fragile.drop(columns='Series Code', inplace=True)
#       2 fragile
#
# File ~/opt/anaconda3/envs/PUBPOL542/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/PUBPOL542/lib/python3.9/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
fragile.reset_index(inplace=True)
fragile
# Out:
#     Country Code                 Country Name    Year Cases  index  \
# 0            AFG                  Afghanistan  2020.0  1500      0
# 1            AFE  Africa Eastern and Southern  2020.0    ..      1
# 2            AFW   Africa Western and Central  2020.0    ..      2
# 3            ALB                      Albania  2020.0   100      3
# 4            DZA                      Algeria  2020.0  2000      4
# ..           ...                          ...     ...   ...    ...
# 537          NaN                          NaN     NaN   NaN    266
# 538          NaN                          NaN     NaN   NaN    267
# 539          NaN                          NaN     NaN   NaN    268
# 540          NaN                          NaN     NaN   NaN    269
# 541          NaN                          NaN     NaN   NaN    270
#
#                                             SeriesName
# 0    Adults (ages 15+) and children (ages 0-14) new...
# ...

# %%
fragile.columns=fragile.columns.str.replace(':|\s',"",regex=True)
fragile
# Out:
#     CountryCode                  CountryName    Year Cases  index  \
# 0           AFG                  Afghanistan  2020.0  1500      0
# 1           AFE  Africa Eastern and Southern  2020.0    ..      1
# 2           AFW   Africa Western and Central  2020.0    ..      2
# 3           ALB                      Albania  2020.0   100      3
# 4           DZA                      Algeria  2020.0  2000      4
# ..          ...                          ...     ...   ...    ...
# 537         NaN                          NaN     NaN   NaN    266
# 538         NaN                          NaN     NaN   NaN    267
# 539         NaN                          NaN     NaN   NaN    268
# 540         NaN                          NaN     NaN   NaN    269
# 541         NaN                          NaN     NaN   NaN    270
#
#                                             SeriesName
# 0    Adults (ages 15+) and children (ages 0-14) new...
# 1    Adults (ages 15+) and children (ages 0-14) new...
# ...

# %%
fragileLong=fragile.iloc[:,:4]
fragileLong
# Out:
#     CountryCode                  CountryName    Year Cases
# 0           AFG                  Afghanistan  2020.0  1500
# 1           AFE  Africa Eastern and Southern  2020.0    ..
# 2           AFW   Africa Western and Central  2020.0    ..
# 3           ALB                      Albania  2020.0   100
# 4           DZA                      Algeria  2020.0  2000
# ..          ...                          ...     ...   ...
# 537         NaN                          NaN     NaN   NaN
# 538         NaN                          NaN     NaN   NaN
# 539         NaN                          NaN     NaN   NaN
# 540         NaN                          NaN     NaN   NaN
# 541         NaN                          NaN     NaN   NaN
#
# [542 rows x 4 columns]

# %%
fragile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  532 non-null    object
#  1   CountryName  532 non-null    object
#  2   Year         532 non-null    float64
#  3   Cases        532 non-null    object
#  4   index        542 non-null    int64
#  5   SeriesName   536 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 25.5+ KB

# %%
fragile.columns.to_list()
# Out:
# ['CountryCode', 'CountryName', 'Year', 'Cases', 'index', 'SeriesName']

# %%
fragile.Cases.value_counts()
# Out:
# ..       269
# 100       36
# 200       23
# 500       18
# 1100      11
#         ...
# 23000      1
# 1300       1
# 7700       1
# 49000      1
# 25000      1
# Name: Cases, Length: 108, dtype: int64

# %%
fragile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  532 non-null    object
#  1   CountryName  532 non-null    object
#  2   Year         532 non-null    float64
#  3   Cases        532 non-null    object
#  4   index        542 non-null    int64
#  5   SeriesName   536 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 25.5+ KB
